# %% [markdown]
# # 지하철 시간대별 데이터 시각화하기
#
# * 출근 시간대 사람들이 가장 많이 타고 내리는 역은 어디일까?
# * 지하철 시간대별로 가장 많은 사람이 승하차 하는 역은 어디일까?
#
# 대중교통 데이터를 바탕으로 질문에 답해보자.

# %%
## 코랩을 사용할 때
#드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

#현재 작업 위치 이동
#띄어쓰기에 \붙일 것
# %cd /content/drive/Othercomputers/내\ 노트북/Devpy_work/13.데이터분석

# %%
#코랩의 경우
# 나눔고딕 폰트 인스톨
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ## 1. 지하철 시간대별 이용 현황 데이터 정제하기
# ---

# %%
import pandas as pd

# %%
# 데이터 로드
df = pd.read_csv('./data/subwaytime.csv',encoding='cp949',thousands=',') # 불러드릴 row위치 지정
df.head()
# Out:
#        사용월  호선명    역ID  지하철역 04:00:00~04:59:59 Unnamed: 5 05:00:00~05:59:59  \
# 0      NaN  NaN    NaN   NaN                승차         하차                승차
# 1  2022-08  1호선  150.0   서울역               573         19             8,638
# 2  2022-08  1호선  151.0    시청                39          0             2,005
# 3  2022-08  1호선  152.0    종각                54          4             3,356
# 4  2022-08  1호선  153.0  종로3가               118         10             3,367
#
#   Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ... Unnamed: 43 00:00:00~00:59:59  \
# 0         하차                승차         하차  ...          하차                승차
# 1      8,274            12,332     45,706  ...      12,503             2,017
# 2      4,665             3,404     23,606  ...       2,631               320
# 3      4,382             3,765     22,971  ...       3,215               970
# 4      3,149             3,409     13,161  ...       3,575             1,177
#
#   Unnamed: 45 01:00:00~01:59:59 Unnamed: 47 02:00:00~02:59:59 Unnamed: 49  \
# 0          하차                승차          하차                승차          하차
# 1       2,148                 0         208                 0           1
# 2         688                 2           7                 0           0
# 3         607                 1           1                 0           0
# 4       1,455                 1          30                 0           0
#
#   03:00:00~03:59:59 Unnamed: 51                 작업일시
# 0                승차          하차                  NaN
# 1                 0           0  2022-09-03 10:18:29
# 2                 0           0  2022-09-03 10:18:29
# 3                 0           0  2022-09-03 10:18:29
# 4                 0           0  2022-09-03 10:18:29
#
# [5 rows x 53 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 53 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   사용월                617 non-null    object
#  1   호선명                617 non-null    object
#  2   역ID                617 non-null    float64
#  3   지하철역               617 non-null    object
#  4   04:00:00~04:59:59  618 non-null    object
#  5   Unnamed: 5         618 non-null    object
#  6   05:00:00~05:59:59  618 non-null    object
#  7   Unnamed: 7         618 non-null    object
#  8   06:00:00~06:59:59  618 non-null    object
#  9   Unnamed: 9         618 non-null    object
#  10  07:00:00~07:59:59  618 non-null    object
#  11  Unnamed: 11        618 non-null    object
#  12  08:00:00~08:59:59  618 non-null    object
#  13  Unnamed: 13        618 non-null    object
#  14  09:00:00~09:59:59  618 non-null    object
#  15  Unnamed: 15        618 non-null    object
#  16  10:00:00~10:59:59  618 non-null    object
#  17  Unnamed: 17        618 non-null    object
#  18  11:00:00~11:59:59  618 non-null    object
#  19  Unnamed: 19        618 non-null    object
#  20  12:00:00~12:59:59  618 non-null    object
#  21  Unnamed: 21        618 non-null    object
#  22  13:00:00~13:59:59  618 non-null    object
#  23  Unnamed: 23        618 non-null    object
#  24  14:00:00~14:59:59  618 non-null    object
#  25  Unnamed: 25        618 non-null    object
#  26  15:00:00~15:59:59  618 non-null    object
#  27  Unnamed: 27        618 non-null    object
#  28  16:00:00~16:59:59  618 non-null    object
#  29  Unnamed: 29        618 non-null    object
#  30  17:00:00~17:59:59  618 non-null    object
#  31  Unnamed: 31        618 non-null    object
#  32  18:00:00~18:59:59  618 non-null    object
#  33  Unnamed: 33        618 non-null    object
#  34  19:00:00~19:59:59  618 non-null    object
#  35  Unnamed: 35        618 non-null    object
#  36  20:00:00~20:59:59  618 non-null    object
#  37  Unnamed: 37        618 non-null    object
#  38  21:00:00~21:59:59  618 non-null    object
#  39  Unnamed: 39        618 non-null    object
#  40  22:00:00~22:59:59  618 non-null    object
#  41  Unnamed: 41        618 non-null    object
#  42  23:00:00~23:59:59  618 non-null    object
#  43  Unnamed: 43        618 non-null    object
#  44  00:00:00~00:59:59  618 non-null    object
#  45  Unnamed: 45        618 non-null    object
#  46  01:00:00~01:59:59  618 non-null    object
#  47  Unnamed: 47        618 non-null    object
#  48  02:00:00~02:59:59  618 non-null    object
#  49  Unnamed: 49        618 non-null    object
#  50  03:00:00~03:59:59  618 non-null    object
#  51  Unnamed: 51        618 non-null    object
#  52  작업일시               617 non-null    object
# dtypes: float64(1), object(52)
# memory usage: 256.0+ KB

# %%
df.columns.size
# Out:
# 53

# %% [markdown]
# ```
# * 이상하게 데이터가 로드됩니다.
# * csv원본을 보고 이유를 찾아야합니다.
# ```

# %% [markdown]
# ## 컬럼이름 새로만들기
#
# 컬럼명 패턴
#
# **사용월 호선명 역ID 지하철명 4_승차 4_하차 5_승차 5_하차 ....... 3_승차 3하차**

# %%
#새로운 컬럼이름으로 만듬
new_cols = ['사용월', '호선명', '역ID', '지하철역']

for i in range(4,24):
    new_cols.append(f'{i}_승차')
    new_cols.append(f'{i}_하차')
for i in range(0,4):
    new_cols.append(f'{i}_승차')
    new_cols.append(f'{i}_하차')

# %%
len(new_cols)
# Out:
# 4

# %%
df.head()
# Out:
#        사용월  호선명    역ID  지하철역 04:00:00~04:59:59 Unnamed: 5 05:00:00~05:59:59  \
# 0      NaN  NaN    NaN   NaN                승차         하차                승차
# 1  2022-08  1호선  150.0   서울역               573         19             8,638
# 2  2022-08  1호선  151.0    시청                39          0             2,005
# 3  2022-08  1호선  152.0    종각                54          4             3,356
# 4  2022-08  1호선  153.0  종로3가               118         10             3,367
#
#   Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ... Unnamed: 43 00:00:00~00:59:59  \
# 0         하차                승차         하차  ...          하차                승차
# 1      8,274            12,332     45,706  ...      12,503             2,017
# 2      4,665             3,404     23,606  ...       2,631               320
# 3      4,382             3,765     22,971  ...       3,215               970
# 4      3,149             3,409     13,161  ...       3,575             1,177
#
#   Unnamed: 45 01:00:00~01:59:59 Unnamed: 47 02:00:00~02:59:59 Unnamed: 49  \
# 0          하차                승차          하차                승차          하차
# 1       2,148                 0         208                 0           1
# 2         688                 2           7                 0           0
# 3         607                 1           1                 0           0
# 4       1,455                 1          30                 0           0
#
#   03:00:00~03:59:59 Unnamed: 51                 작업일시
# 0                승차          하차                  NaN
# 1                 0           0  2022-09-03 10:18:29
# 2                 0           0  2022-09-03 10:18:29
# 3                 0           0  2022-09-03 10:18:29
# 4                 0           0  2022-09-03 10:18:29
#
# [5 rows x 53 columns]

# %%
#작업일시를 제외하고 데이터만 추출
value = df.iloc[1:, :-1].values

# %%
#새롭게 만든 컬럼 이름으로 새로운 데이터프레임을 만듬
new_df = pd.DataFrame(data=value,columns=new_cols)
new_df.head()
# Out:
#        사용월  호선명    역ID  지하철역 4_승차 4_하차   5_승차   5_하차    6_승차    6_하차  ...  \
# 0  2022-08  1호선  150.0   서울역  573   19  8,638  8,274  12,332  45,706  ...
# 1  2022-08  1호선  151.0    시청   39    0  2,005  4,665   3,404  23,606  ...
# 2  2022-08  1호선  152.0    종각   54    4  3,356  4,382   3,765  22,971  ...
# 3  2022-08  1호선  153.0  종로3가  118   10  3,367  3,149   3,409  13,161  ...
# 4  2022-08  1호선  154.0  종로5가   38    2  1,632  3,635   2,766  15,329  ...
#
#     23_승차   23_하차   0_승차   0_하차 1_승차 1_하차 2_승차 2_하차 3_승차 3_하차
# 0  22,497  12,503  2,017  2,148    0  208    0    1    0    0
# 1   8,948   2,631    320    688    2    7    0    0    0    0
# 2  26,636   3,215    970    607    1    1    0    0    0    0
# 3  14,726   3,575  1,177  1,455    1   30    0    0    0    0
# 4   5,541   2,481    194    728    1    1    0    0    0    0
#
# [5 rows x 52 columns]

# %% [markdown]
# ```
# 승하차와 관련한 숫자들의 타입이 object이다. 문자열이라는 의미
# 숫자로 형변환이 필요하겠다.
# ```

# %%
#형변환을 하기위해
#승하차 관련 컬럼들에서 콤마 삭제

for col in new_df.columns[4:]:
    new_df[col] = new_df[col].str.replace(',','')

# %%
new_df.head()
# Out:
#        사용월  호선명    역ID  지하철역 4_승차 4_하차  5_승차  5_하차   6_승차   6_하차  ...  23_승차  \
# 0  2022-08  1호선  150.0   서울역  573   19  8638  8274  12332  45706  ...  22497
# 1  2022-08  1호선  151.0    시청   39    0  2005  4665   3404  23606  ...   8948
# 2  2022-08  1호선  152.0    종각   54    4  3356  4382   3765  22971  ...  26636
# 3  2022-08  1호선  153.0  종로3가  118   10  3367  3149   3409  13161  ...  14726
# 4  2022-08  1호선  154.0  종로5가   38    2  1632  3635   2766  15329  ...   5541
#
#    23_하차  0_승차  0_하차 1_승차 1_하차 2_승차 2_하차 3_승차 3_하차
# 0  12503  2017  2148    0  208    0    1    0    0
# 1   2631   320   688    2    7    0    0    0    0
# 2   3215   970   607    1    1    0    0    0    0
# 3   3575  1177  1455    1   30    0    0    0    0
# 4   2481   194   728    1    1    0    0    0    0
#
# [5 rows x 52 columns]

# %%
for col in new_df.columns[4:]:
    new_df[col] = new_df[col].astype('int64')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 52 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용월     617 non-null    object
#  1   호선명     617 non-null    object
#  2   역ID     617 non-null    object
#  3   지하철역    617 non-null    object
#  4   4_승차    617 non-null    int64
#  5   4_하차    617 non-null    int64
#  6   5_승차    617 non-null    int64
#  7   5_하차    617 non-null    int64
#  8   6_승차    617 non-null    int64
#  9   6_하차    617 non-null    int64
#  10  7_승차    617 non-null    int64
#  11  7_하차    617 non-null    int64
#  12  8_승차    617 non-null    int64
#  13  8_하차    617 non-null    int64
#  14  9_승차    617 non-null    int64
#  15  9_하차    617 non-null    int64
#  16  10_승차   617 non-null    int64
#  17  10_하차   617 non-null    int64
#  18  11_승차   617 non-null    int64
#  19  11_하차   617 non-null    int64
#  20  12_승차   617 non-null    int64
#  21  12_하차   617 non-null    int64
#  22  13_승차   617 non-null    int64
#  23  13_하차   617 non-null    int64
#  24  14_승차   617 non-null    int64
#  25  14_하차   617 non-null    int64
#  26  15_승차   617 non-null    int64
#  27  15_하차   617 non-null    int64
#  28  16_승차   617 non-null    int64
#  29  16_하차   617 non-null    int64
#  30  17_승차   617 non-null    int64
#  31  17_하차   617 non-null    int64
#  32  18_승차   617 non-null    int64
#  33  18_하차   617 non-null    int64
#  34  19_승차   617 non-null    int64
#  35  19_하차   617 non-null    int64
#  36  20_승차   617 non-null    int64
#  37  20_하차   617 non-null    int64
#  38  21_승차   617 non-null    int64
#  39  21_하차   617 non-null    int64
#  40  22_승차   617 non-null    int64
#  41  22_하차   617 non-null    int64
#  42  23_승차   617 non-null    int64
#  43  23_하차   617 non-null    int64
#  44  0_승차    617 non-null    int64
#  45  0_하차    617 non-null    int64
#  46  1_승차    617 non-null    int64
#  47  1_하차    617 non-null    int64
#  48  2_승차    617 non-null    int64
#  49  2_하차    617 non-null    int64
#  50  3_승차    617 non-null    int64
#  51  3_하차    617 non-null    int64
# dtypes: int64(48), object(4)
# memory usage: 250.8+ KB

# %% [markdown]
# ## 2. 출근 시간대 사람들이 가장 많이 타고 내리는 역은 어디일까
# ---
# 아침 7시 승차 데이터의 위치를 확인하니 10번 인덱스에 저장되었있음을 확인할 수 있다.

# %%
new_df['7_승차']
# Out:
# 0      39560
# 1       6430
# 2       5801
# 3       4642
# 4       5251
#        ...
# 612     9575
# 613     3212
# 614    10158
# 615    19371
# 616     4375
# Name: 7_승차, Length: 617, dtype: int64

# %% [markdown]
# 이 결과를 막대그래프로 표현해보자.

# %%
len(new_df)
# Out:
# 617

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot') #스타일 지정
plt.figure(figsize=(6, 4)) #스케치북 사이즈

plt.bar( range(len(new_df)) ,new_df['7_승차'] ) # X, Y 꼭 지정

plt.show()

# %% [markdown]
# 편차가 매우 크다. 데이터를 오름차순으로 정렬해보자.

# %% [markdown]
# 한개의 역이 다른 역들과는 큰 차이를 두고 많다는 것을 알 수 있다.
#
# 그러면 출근 시간대라고 할 수 있는 7-9시까지 승차 인원을 합치면 어떻게 될까?

# %%
new_df['출근시간대_승차합계'] = new_df['7_승차'] +new_df['8_승차'] +new_df['9_승차']
new_df.head()
# Out:
#        사용월  호선명    역ID  지하철역  4_승차  4_하차  5_승차  5_하차   6_승차   6_하차  ...  \
# 0  2022-08  1호선  150.0   서울역   573    19  8638  8274  12332  45706  ...
# 1  2022-08  1호선  151.0    시청    39     0  2005  4665   3404  23606  ...
# 2  2022-08  1호선  152.0    종각    54     4  3356  4382   3765  22971  ...
# 3  2022-08  1호선  153.0  종로3가   118    10  3367  3149   3409  13161  ...
# 4  2022-08  1호선  154.0  종로5가    38     2  1632  3635   2766  15329  ...
#
#    23_하차  0_승차  0_하차  1_승차  1_하차  2_승차  2_하차  3_승차  3_하차  출근시간대_승차합계
# 0  12503  2017  2148     0   208     0     1     0     0      154546
# 1   2631   320   688     2     7     0     0     0     0       25005
# 2   3215   970   607     1     1     0     0     0     0       27170
# 3   3575  1177  1455     1    30     0     0     0     0       25674
# 4   2481   194   728     1     1     0     0     0     0       26373
#
# [5 rows x 53 columns]

# %%
df.head()
# Out:
#        사용월  호선명    역ID  지하철역 04:00:00~04:59:59 Unnamed: 5 05:00:00~05:59:59  \
# 0      NaN  NaN    NaN   NaN                승차         하차                승차
# 1  2022-08  1호선  150.0   서울역               573         19             8,638
# 2  2022-08  1호선  151.0    시청                39          0             2,005
# 3  2022-08  1호선  152.0    종각                54          4             3,356
# 4  2022-08  1호선  153.0  종로3가               118         10             3,367
#
#   Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ... Unnamed: 43 00:00:00~00:59:59  \
# 0         하차                승차         하차  ...          하차                승차
# 1      8,274            12,332     45,706  ...      12,503             2,017
# 2      4,665             3,404     23,606  ...       2,631               320
# 3      4,382             3,765     22,971  ...       3,215               970
# 4      3,149             3,409     13,161  ...       3,575             1,177
#
#   Unnamed: 45 01:00:00~01:59:59 Unnamed: 47 02:00:00~02:59:59 Unnamed: 49  \
# 0          하차                승차          하차                승차          하차
# 1       2,148                 0         208                 0           1
# 2         688                 2           7                 0           0
# 3         607                 1           1                 0           0
# 4       1,455                 1          30                 0           0
#
#   03:00:00~03:59:59 Unnamed: 51                 작업일시
# 0                승차          하차                  NaN
# 1                 0           0  2022-09-03 10:18:29
# 2                 0           0  2022-09-03 10:18:29
# 3                 0           0  2022-09-03 10:18:29
# 4                 0           0  2022-09-03 10:18:29
#
# [5 rows x 53 columns]

# %%
new_df.sort_values(by='출근시간대_승차합계',ascending=False).iloc[0,3]
# Out:
# '신림'

# %% [markdown]
# ```
# 시간대를 늘렸지만 그래프의 형태는 거의 비슷하다.
# 3시간 동안 60만명이 들어오는 역은 어딜까?
# ```

# %% [markdown]
# 그러면 출근 시간대에 사람들이 가장 많이 내리는 역은 어디일까?

# %% [markdown]
# ## 3. 밤 11시에 사람들이 가장 많이 타는 역은 어디일까
# ---

# %%
import pandas as pd

df = pd.read_csv('./data/subwaytime.csv',encoding='cp949')

#새로운 컬럼이름으로 만듬
new_cols = ['사용월', '호선명', '역ID', '지하철역']

for i in range(4,24):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

for i in range(0,4):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

#데이터프레임에서 컬럼영역을 제외하고 데이터만 추출
value = df.iloc[1:,:-1].values

#새롭게 만든 컬럼 이름으로 새로운 데이터프레임을 만듬
new_df = pd.DataFrame(data=value,columns=new_cols)

#형변환을 하기위해
#승하차 관련 컬럼들에서 콤마 삭제

for col in new_df.columns[4:]:
    new_df[col] = new_df[col].str.replace(',','')
for col in new_df.columns[4:]:
    new_df[col] = new_df[col].astype('int64')

# %%
#23시 승차로 정렬

# %%
#밤 11시에 사람들이 가장 많이 타는 역은?

# %% [markdown]
# ## 4. 시간대별로 사람들이 가장 많이 타고 내리는 역은 어디일까
# ---

# %%
import pandas as pd

df = pd.read_csv('./data/subwaytime.csv',encoding='cp949')

#새로운 컬럼이름으로 만듬
new_cols = ['사용월', '호선명', '역ID', '지하철역']

for i in range(4,24):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

for i in range(0,4):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

#데이터프레임에서 컬럼영역을 제외하고 데이터만 추출
value = df.iloc[1:,:-1].values

#새롭게 만든 컬럼 이름으로 새로운 데이터프레임을 만듬
new_df = pd.DataFrame(data=value,columns=new_cols)

#형변환을 하기위해
#승하차 관련 컬럼들에서 콤마 삭제

for col in new_df.columns[4:]:
    new_df[col] = new_df[col].str.replace(',','')
for col in new_df.columns[4:]:
    new_df[col] = new_df[col].astype('int64')

# %%
name_lst = []
count_lst = []

# %% [markdown]
# 이 데이터를 바탕으로 막대그래프를 그려보자.

# %%
import matplotlib.pyplot as plt
plt.rc('font', family ='NanumGothic')

plt.bar(range(24), count_lst)
plt.xticks(range(24), name_lst , rotation =90)
plt.show()

# %% [markdown]
# x축에 시간이 표시되어 있지 않아서 알아보기 어렵다.

# %%
name_lst = []
count_lst = []

# %%
plt.bar(range(24), count_lst)
plt.xticks(range(24), name_lst , rotation =90)
plt.show()

# %% [markdown]
# ## 5. 모든 지하철역에서 시간대별 승하차 인원을 모두 더하면
# ---
# __만약 모든 지하철역의 시간대별 승하차 인원을 더하면 어떤 결과를 확인할 수 있을까?__
#
# 이 질문을 해결하기 위한 알고리즘은 다음과 같이 간단히 생각할 수 있다.
#
# 1. 데이터를 읽어온다.
# 2. 모든 역에 대해 시간대별 승차 인원과 하차 인원을 누적해서 더한다.
# 3. 시간대별 승차 인원과 하차 인원을 그래프로 표현한다.

# %%
import pandas as pd

df = pd.read_csv('./data/subwaytime.csv',encoding='cp949')

#새로운 컬럼이름으로 만듬
new_cols = ['사용월', '호선명', '역ID', '지하철역']

for i in range(4,24):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

for i in range(0,4):
    txt1 = str(i) + '_승차'
    new_cols.append(txt1)
    
    txt2 = str(i) + '_하차'
    new_cols.append(txt2)

#데이터프레임에서 컬럼영역을 제외하고 데이터만 추출
value = df.iloc[1:,:-1].values

#새롭게 만든 컬럼 이름으로 새로운 데이터프레임을 만듬
new_df = pd.DataFrame(data=value,columns=new_cols)

#형변환을 하기위해
#승하차 관련 컬럼들에서 콤마 삭제

for col in new_df.columns[4:]:
    new_df[col] = new_df[col].str.replace(',','')
for col in new_df.columns[4:]:
    new_df[col] = new_df[col].astype('int64')

    
new_df.head()

# %%
#컬럼별 총합

# %%
#새로운 데이터프레임으로 만들기

# %%
s_in = []
s_out = []

# %% [markdown]
# > * 출근 시간대는 7-8시, 8-9시에 승차 인원이 많고, 하차 인원은 8-9시가 눈에 띄게 많습니다.
# > * 퇴근 시간대는 승차는 18-19시에 눈에 띄게 많고, 하차는 18-19시, 19-20시에 가장 많은 것을 볼 수 있습니다.
