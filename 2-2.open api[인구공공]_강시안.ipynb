# %% [markdown]
# # 우리 동네 인구 구조 시각화 하기
# https://jumin.mois.go.kr/index.jsp#

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## 데이터 기초 정보 파악

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터 로드
# df = pd.read_csv('./data/population.csv',encoding='utf-8-sig')
# df = pd.read_csv('./data/population.csv',encoding='utf-8')
df = pd.read_csv('./data/population.csv')
# df = pd.read_csv('./data/population.csv',encoding='cp949')

# %%
df.head()
# Out:
#                           행정구역     남_총인구수  남_연령구간인구수    남_0세    남_1세    남_2세  \
# 0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115  23,013  23,458
# 1       서울특별시 종로구 (1111000000)     69,408     69,408     232     248     270
# 2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24      24      28
# 3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17      14      15
# 4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2       3       2
#
#      남_3세    남_4세    남_5세    남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 0  25,684  26,926  29,115  33,125  ...  5,718  4,987  4,157  3,135  2,326
# 1     261     299     320     426  ...    126    104     78     77     49
# 2      21      27      44      47  ...     13      4      6      5      2
# 3      21      24      30      37  ...     13      8      8      3      2
# 4       2       4       4       6  ...      1      5      0      2      0
#
#    여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  1,504  1,032   773   704     1,292
# 1     29     20    13    15        28
# 2      3      0     2     1         2
# 3      4      3     0     3         0
# 4      0      1     0     0         2
#
# [5 rows x 207 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3867 entries, 0 to 3866
# Columns: 207 entries, 행정구역 to 여_100세 이상
# dtypes: int64(8), object(199)
# memory usage: 6.1+ MB

# %%
df.columns
# Out:
# Index(['행정구역', '남_총인구수', '남_연령구간인구수', '남_0세', '남_1세', '남_2세', '남_3세', '남_4세',
#        '남_5세', '남_6세',
#        ...
#        '여_91세', '여_92세', '여_93세', '여_94세', '여_95세', '여_96세', '여_97세', '여_98세',
#        '여_99세', '여_100세 이상'],
#       dtype='object', length=207)

# %%
for col in df.columns:
    print(col)
# Out:
# 행정구역
# 남_총인구수
# 남_연령구간인구수
# 남_0세
# 남_1세
# 남_2세
# 남_3세
# 남_4세
# 남_5세
# 남_6세
# 남_7세
# 남_8세
# 남_9세
# 남_10세
# 남_11세
# 남_12세
# 남_13세
# 남_14세
# 남_15세
# 남_16세
# 남_17세
# 남_18세
# 남_19세
# 남_20세
# 남_21세
# 남_22세
# 남_23세
# 남_24세
# 남_25세
# 남_26세
# 남_27세
# 남_28세
# 남_29세
# 남_30세
# 남_31세
# 남_32세
# 남_33세
# 남_34세
# 남_35세
# 남_36세
# 남_37세
# 남_38세
# 남_39세
# 남_40세
# 남_41세
# 남_42세
# 남_43세
# 남_44세
# 남_45세
# 남_46세
# 남_47세
# 남_48세
# 남_49세
# 남_50세
# 남_51세
# 남_52세
# 남_53세
# 남_54세
# 남_55세
# 남_56세
# 남_57세
# 남_58세
# 남_59세
# 남_60세
# 남_61세
# 남_62세
# 남_63세
# 남_64세
# 남_65세
# 남_66세
# 남_67세
# 남_68세
# 남_69세
# 남_70세
# 남_71세
# 남_72세
# 남_73세
# 남_74세
# 남_75세
# 남_76세
# 남_77세
# 남_78세
# 남_79세
# 남_80세
# 남_81세
# 남_82세
# 남_83세
# 남_84세
# 남_85세
# 남_86세
# 남_87세
# 남_88세
# 남_89세
# 남_90세
# 남_91세
# 남_92세
# 남_93세
# 남_94세
# 남_95세
# 남_96세
# 남_97세
# 남_98세
# 남_99세
# 남_100세 이상
# 여_총인구수
# 여_연령구간인구수
# 여_0세
# 여_1세
# 여_2세
# 여_3세
# 여_4세
# 여_5세
# 여_6세
# 여_7세
# 여_8세
# 여_9세
# 여_10세
# 여_11세
# 여_12세
# 여_13세
# 여_14세
# 여_15세
# 여_16세
# 여_17세
# 여_18세
# 여_19세
# 여_20세
# 여_21세
# 여_22세
# 여_23세
# 여_24세
# 여_25세
# 여_26세
# 여_27세
# 여_28세
# 여_29세
# 여_30세
# 여_31세
# 여_32세
# 여_33세
# 여_34세
# 여_35세
# 여_36세
# 여_37세
# 여_38세
# 여_39세
# 여_40세
# 여_41세
# 여_42세
# 여_43세
# 여_44세
# 여_45세
# 여_46세
# 여_47세
# 여_48세
# 여_49세
# 여_50세
# 여_51세
# 여_52세
# 여_53세
# 여_54세
# 여_55세
# 여_56세
# 여_57세
# 여_58세
# 여_59세
# 여_60세
# 여_61세
# 여_62세
# 여_63세
# 여_64세
# 여_65세
# 여_66세
# 여_67세
# 여_68세
# 여_69세
# 여_70세
# 여_71세
# 여_72세
# 여_73세
# 여_74세
# 여_75세
# 여_76세
# 여_77세
# 여_78세
# 여_79세
# 여_80세
# 여_81세
# 여_82세
# 여_83세
# 여_84세
# 여_85세
# 여_86세
# 여_87세
# 여_88세
# 여_89세
# 여_90세
# 여_91세
# 여_92세
# 여_93세
# 여_94세
# 여_95세
# 여_96세
# 여_97세
# 여_98세
# 여_99세
# 여_100세 이상

# %%
#컬럼명 2022년08월_ 삭제

df.columns.str.replace('2022년08월_','')
# Out:
# Index(['행정구역', '남_총인구수', '남_연령구간인구수', '남_0세', '남_1세', '남_2세', '남_3세', '남_4세',
#        '남_5세', '남_6세',
#        ...
#        '여_91세', '여_92세', '여_93세', '여_94세', '여_95세', '여_96세', '여_97세', '여_98세',
#        '여_99세', '여_100세 이상'],
#       dtype='object', length=207)

# %%
df.columns
# Out:
# Index(['행정구역', '남_총인구수', '남_연령구간인구수', '남_0세', '남_1세', '남_2세', '남_3세', '남_4세',
#        '남_5세', '남_6세',
#        ...
#        '여_91세', '여_92세', '여_93세', '여_94세', '여_95세', '여_96세', '여_97세', '여_98세',
#        '여_99세', '여_100세 이상'],
#       dtype='object', length=207)

# %%
df.columns = df.columns.str.replace('2022년08월_','')

# %%
df.columns
# Out:
# Index(['행정구역', '남_총인구수', '남_연령구간인구수', '남_0세', '남_1세', '남_2세', '남_3세', '남_4세',
#        '남_5세', '남_6세',
#        ...
#        '여_91세', '여_92세', '여_93세', '여_94세', '여_95세', '여_96세', '여_97세', '여_98세',
#        '여_99세', '여_100세 이상'],
#       dtype='object', length=207)

# %%
df.head()
# Out:
#                           행정구역     남_총인구수  남_연령구간인구수    남_0세    남_1세    남_2세  \
# 0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115  23,013  23,458
# 1       서울특별시 종로구 (1111000000)     69,408     69,408     232     248     270
# 2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24      24      28
# 3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17      14      15
# 4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2       3       2
#
#      남_3세    남_4세    남_5세    남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 0  25,684  26,926  29,115  33,125  ...  5,718  4,987  4,157  3,135  2,326
# 1     261     299     320     426  ...    126    104     78     77     49
# 2      21      27      44      47  ...     13      4      6      5      2
# 3      21      24      30      37  ...     13      8      8      3      2
# 4       2       4       4       6  ...      1      5      0      2      0
#
#    여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  1,504  1,032   773   704     1,292
# 1     29     20    13    15        28
# 2      3      0     2     1         2
# 3      4      3     0     3         0
# 4      0      1     0     0         2
#
# [5 rows x 207 columns]

# %%
#전처리한 데이터프레임 저장

# df.to_csv('./data/population_new.csv')
df.to_csv('./data/population_new.csv', index = False) #index 제외하고 저장하기

# %%
# new_df=pd.read_csv('./data/population_new.csv',index_col=0)

# new_df.head()

# %%
df = pd.read_csv('./data/population_new.csv')
df.head()
# Out:
#                           행정구역     남_총인구수  남_연령구간인구수    남_0세    남_1세    남_2세  \
# 0          서울특별시  (1100000000)  4,601,295  4,601,295  21,115  23,013  23,458
# 1       서울특별시 종로구 (1111000000)     69,408     69,408     232     248     270
# 2  서울특별시 종로구 청운효자동(1111051500)      5,392      5,392      24      24      28
# 3    서울특별시 종로구 사직동(1111053000)      4,124      4,124      17      14      15
# 4    서울특별시 종로구 삼청동(1111054000)      1,130      1,130       2       3       2
#
#      남_3세    남_4세    남_5세    남_6세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 0  25,684  26,926  29,115  33,125  ...  5,718  4,987  4,157  3,135  2,326
# 1     261     299     320     426  ...    126    104     78     77     49
# 2      21      27      44      47  ...     13      4      6      5      2
# 3      21      24      30      37  ...     13      8      8      3      2
# 4       2       4       4       6  ...      1      5      0      2      0
#
#    여_96세  여_97세 여_98세 여_99세 여_100세 이상
# 0  1,504  1,032   773   704     1,292
# 1     29     20    13    15        28
# 2      3      0     2     1         2
# 3      4      3     0     3         0
# 4      0      1     0     0         2
#
# [5 rows x 207 columns]

# %%
#남자만 출력

df.iloc[ : , 3:104]
# Out:
#         남_0세    남_1세    남_2세    남_3세    남_4세    남_5세    남_6세    남_7세    남_8세  \
# 0     21,115  23,013  23,458  25,684  26,926  29,115  33,125  34,405  34,172
# 1        232     248     270     261     299     320     426     399     415
# 2         24      24      28      21      27      44      47      44      46
# 3         17      14      15      21      24      30      37      45      24
# 4          2       3       2       2       4       4       6       7       4
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3862      37      41      44      52      51      58      74      86      75
# 3863      63      76      92      80      82      86      86     103      89
# 3864      57      56      64      63      86      93     107     101      88
# 3865      41      28      53      45      44      49      62      68      47
# 3866       3      10       6      11      12      15      11      15      14
#
#         남_9세  ...  남_91세  남_92세  남_93세 남_94세 남_95세 남_96세 남_97세 남_98세 남_99세  \
# 0     35,784  ...  2,102  1,649  1,474   978   664   392   301   240   246
# 1        451  ...     52     37     44    13    26    18    12     9     8
# 2         51  ...      2      3      1     0     4     1     3     1     0
# 3         36  ...      3      1     10     2     4     4     2     2     1
# 4          7  ...      2      2      1     1     2     1     0     1     0
# ...      ...  ...    ...    ...    ...   ...   ...   ...   ...   ...   ...
# 3862      80  ...      4      1      1     1     0     0     0     1     0
# 3863      81  ...      4      3      1     2     0     0     0     0     0
# 3864      92  ...      2      1      0     1     1     1     0     0     0
# 3865      67  ...      4      1      4     0     0     1     0     0     0
# 3866      11  ...      1      2      1     1     0     0     0     0     0
#
#      남_100세 이상
# 0          414
# 1           15
# 2            1
# 3            1
# 4            2
# ...        ...
# 3862         1
# 3863         0
# 3864         1
# 3865         0
# 3866         0
#
# [3867 rows x 101 columns]

# %%
#여자만 출력
df.iloc[ :,106:    ]
# Out:
#         여_0세    여_1세    여_2세    여_3세    여_4세    여_5세    여_6세    여_7세    여_8세  \
# 0     19,816  21,718  22,053  23,561  25,352  27,939  31,868  32,984  32,286
# 1        212     236     260     284     281     336     395     382     445
# 2         24      22      20      31      25      36      39      44      53
# 3         17      16      21      22      21      33      32      24      48
# 4          2       4       3       3       9       4       6       6       6
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3862      42      40      34      51      61      66      82      89      84
# 3863      58      47      58      61      74      89      80      93      69
# 3864      43      46      54      57      64      86     104      90     112
# 3865      36      35      35      48      36      45      59      56      65
# 3866       9       4       5       6       7       8      11      15      16
#
#         여_9세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  여_96세  여_97세 여_98세  \
# 0     33,944  ...  5,718  4,987  4,157  3,135  2,326  1,504  1,032   773
# 1        440  ...    126    104     78     77     49     29     20    13
# 2         44  ...     13      4      6      5      2      3      0     2
# 3         29  ...     13      8      8      3      2      4      3     0
# 4          7  ...      1      5      0      2      0      0      1     0
# ...      ...  ...    ...    ...    ...    ...    ...    ...    ...   ...
# 3862      86  ...      8      3      4      6      0      2      0     0
# 3863      89  ...     11     14      6      6      5      4      2     1
# 3864      72  ...      8     17      3      8      4      4      0     1
# 3865      70  ...      8      9      9      6      4      4      1     0
# 3866      17  ...     11     10      2      3      3      1      0     0
#
#      여_99세 여_100세 이상
# 0      704     1,292
# 1       15        28
# 2        1         2
# 3        3         0
# 4        0         2
# ...    ...       ...
# 3862     2         1
# 3863     5         7
# 3864     1         2
# 3865     2         2
# 3866     1         1
#
# [3867 rows x 101 columns]

# %%
df.isnull().sum().sum() #결측치 0건
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3867 entries, 0 to 3866
# Columns: 207 entries, 행정구역 to 여_100세 이상
# dtypes: int64(8), object(199)
# memory usage: 6.1+ MB

# %%
df.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 df.astype('int64')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1098, in astype_nansafe(arr, dtype, copy, skipna)
#    1096 if arr.ndim > 1:
#    1097     flat = arr.ravel()
# -> 1098     result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1099     # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1100     # attribute "reshape"
#    1101     return result.reshape(arr.shape)  # type: ignore[union-attr]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '서울특별시  (1100000000)'

# %%
df.iloc[:,1:].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 df.iloc[:,1:].astype('int64')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1098, in astype_nansafe(arr, dtype, copy, skipna)
#    1096 if arr.ndim > 1:
#    1097     flat = arr.ravel()
# -> 1098     result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1099     # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1100     # attribute "reshape"
#    1101     return result.reshape(arr.shape)  # type: ignore[union-attr]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '4,601,295'

# %% [markdown]
# ## 데이터 전처리
# * 불필요 데이터 삭제
# * 컬럼0번째를 인덱스로 설정

# %%
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0, thousands=',')

df.head()
# Out:
#                               남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세   남_3세  \
# 행정구역
# 서울특별시  (1100000000)          4601295    4601295  21115  23013  23458  25684
# 서울특별시 종로구 (1111000000)         69408      69408    232    248    270    261
# 서울특별시 종로구 청운효자동(1111051500)     5392       5392     24     24     28     21
# 서울특별시 종로구 사직동(1111053000)       4124       4124     17     14     15     21
# 서울특별시 종로구 삼청동(1111054000)       1130       1130      2      3      2      2
#
#                               남_4세   남_5세   남_6세   남_7세  ...  여_91세  여_92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          26926  29115  33125  34405  ...   5718   4987
# 서울특별시 종로구 (1111000000)         299    320    426    399  ...    126    104
# 서울특별시 종로구 청운효자동(1111051500)     27     44     47     44  ...     13      4
# 서울특별시 종로구 사직동(1111053000)       24     30     37     45  ...     13      8
# 서울특별시 종로구 삼청동(1111054000)        4      4      6      7  ...      1      5
#
#                              여_93세  여_94세  여_95세  여_96세  여_97세  여_98세  여_99세  \
# 행정구역
# 서울특별시  (1100000000)           4157   3135   2326   1504   1032    773    704
# 서울특별시 종로구 (1111000000)          78     77     49     29     20     13     15
# 서울특별시 종로구 청운효자동(1111051500)      6      5      2      3      0      2      1
# 서울특별시 종로구 사직동(1111053000)        8      3      2      4      3      0      3
# 서울특별시 종로구 삼청동(1111054000)        0      2      0      0      1      0      0
#
#                              여_100세 이상
# 행정구역
# 서울특별시  (1100000000)               1292
# 서울특별시 종로구 (1111000000)              28
# 서울특별시 종로구 청운효자동(1111051500)          2
# 서울특별시 종로구 사직동(1111053000)            0
# 서울특별시 종로구 삼청동(1111054000)            2
#
# [5 rows x 206 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3867 entries, 서울특별시  (1100000000) to 제주특별자치도 서귀포시 예래동(5013062000)
# Columns: 206 entries, 남_총인구수 to 여_100세 이상
# dtypes: int64(206)
# memory usage: 6.1+ MB

# %% [markdown]
# > **[데이터에 대한 질문]**
# > * 종로구의 인구구조는 어떨까?
# > * 부산시 남구 문현동의 인구구조는 어떨가?
# >
# >

# %%
# 불필요한 데이터 삭제

#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']

# %%
df.head()
# Out:
#                               남_총인구수  남_연령구간인구수   남_0세   남_1세   남_2세   남_3세  \
# 행정구역
# 서울특별시  (1100000000)          4601295    4601295  21115  23013  23458  25684
# 서울특별시 종로구 (1111000000)         69408      69408    232    248    270    261
# 서울특별시 종로구 청운효자동(1111051500)     5392       5392     24     24     28     21
# 서울특별시 종로구 사직동(1111053000)       4124       4124     17     14     15     21
# 서울특별시 종로구 삼청동(1111054000)       1130       1130      2      3      2      2
#
#                               남_4세   남_5세   남_6세   남_7세  ...  여_91세  여_92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          26926  29115  33125  34405  ...   5718   4987
# 서울특별시 종로구 (1111000000)         299    320    426    399  ...    126    104
# 서울특별시 종로구 청운효자동(1111051500)     27     44     47     44  ...     13      4
# 서울특별시 종로구 사직동(1111053000)       24     30     37     45  ...     13      8
# 서울특별시 종로구 삼청동(1111054000)        4      4      6      7  ...      1      5
#
#                              여_93세  여_94세  여_95세  여_96세  여_97세  여_98세  여_99세  \
# 행정구역
# 서울특별시  (1100000000)           4157   3135   2326   1504   1032    773    704
# 서울특별시 종로구 (1111000000)          78     77     49     29     20     13     15
# 서울특별시 종로구 청운효자동(1111051500)      6      5      2      3      0      2      1
# 서울특별시 종로구 사직동(1111053000)        8      3      2      4      3      0      3
# 서울특별시 종로구 삼청동(1111054000)        0      2      0      0      1      0      0
#
#                              여_100세 이상
# 행정구역
# 서울특별시  (1100000000)               1292
# 서울특별시 종로구 (1111000000)              28
# 서울특별시 종로구 청운효자동(1111051500)          2
# 서울특별시 종로구 사직동(1111053000)            0
# 서울특별시 종로구 삼청동(1111054000)            2
#
# [5 rows x 206 columns]

# %%
name = '아름동'

# %%
# 아름동이 있는지 확인
mytown = df[df.index.str.contains('아름동')]
print(mytown)
# Out:
#                           남_0세  남_1세  남_2세  남_3세  남_4세  남_5세  남_6세  남_7세  \
# 행정구역
# 세종특별자치시  아름동(3611053000)    97   103    91   128   141   160   182   212
#
#                           남_8세  남_9세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 행정구역                                  ...
# 세종특별자치시  아름동(3611053000)   213   203  ...      3      6      5      2      2
#
#                           여_96세  여_97세  여_98세  여_99세  여_100세 이상
# 행정구역
# 세종특별자치시  아름동(3611053000)      3      2      0      1          0
#
# [1 rows x 202 columns]

# %% [markdown]
# # 우리동네 연령별 인구구조
# * 남, 여 데이터 각각 추출

# %%
#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

# %%
male.shape, female.shape
# Out:
# ((1, 101), (1, 101))

# %%
#연령별 남여 합계 계산
total = []

for i in range(0,101):
    # print(male.iloc[0,i])
    
    total.append(male.iloc[0,i] + female.iloc[0,i])

# %%
male.iloc[0,0], female.iloc[0,0]
# Out:
# (97, 81)

# %%
total[0]
# Out:
# 178

# %% [markdown]
# ## line 차트

# %%
name = '아름동'
plt.figure(figsize=(5,3)) #figure 사이즈 조절
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.plot(total)

plt.show()

# %% [markdown]
# > * 젊은 부부가 많이 사는 동네로 보입니다.
# > * 어린아이와 40대가 많이 살고 있고,
# > * 반면 노년층이 적습니다.

# %% [markdown]
# ---
# ## 종합코드

# %%
# 데이터 로드

# 전처리

# 동네이름 ()

# 시각화

# 분석내용~~

# %%
mytown = df[df.index.str.contains('동래구 명륜동')]

# %%
print(mytown)
# Out:
#                            남_0세  남_1세  남_2세  남_3세  남_4세  남_5세  남_6세  남_7세  \
# 행정구역
# 부산광역시 동래구 명륜동(2626054500)    70    96    87   114   117   131   174   183
#
#                            남_8세  남_9세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 행정구역                                   ...
# 부산광역시 동래구 명륜동(2626054500)   185   186  ...      5     20      9      5      7
#
#                            여_96세  여_97세  여_98세  여_99세  여_100세 이상
# 행정구역
# 부산광역시 동래구 명륜동(2626054500)      4      0      1      0          1
#
# [1 rows x 202 columns]

# %%
name = '동래구 명륜동'
plt.figure(figsize=(5,3)) #figure 사이즈 조절
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.plot(total)

plt.show()

# %% [markdown]
# > * 40대 부부 및 중년층이 많이 사는 동네로 보입니다.
# > * 10대 청소년층의 인구 수와 60대의 인구수가 비슷한 것으로 보입니다.
# > * 10대 미만의 인구 수와 30대 및 70대 인구수가 비슷한 것으로 보입니다.

# %% [markdown]
# ## Bar 차트
# * bar차트는 두 종류의 값들이 입력됩니다.
# * bar(막대를 표시할 위치, 막대 높이)
# * 두 종류의 값들은 개수가 일치해야 합니다.

# %%
total
# Out:
# [178,
#  219,
#  199,
#  269,
#  260,
#  316,
#  357,
#  383,
#  386,
#  428,
#  493,
#  515,
#  499,
#  490,
#  468,
#  426,
#  425,
#  390,
#  392,
#  322,
#  284,
#  284,
#  232,
#  179,
#  130,
#  127,
#  120,
#  149,
#  147,
#  197,
#  205,
#  227,
#  239,
#  279,
#  258,
#  324,
#  323,
#  385,
#  403,
#  431,
#  520,
#  578,
#  630,
#  584,
#  582,
#  573,
#  567,
#  570,
#  613,
#  538,
#  462,
#  494,
#  399,
#  354,
#  324,
#  248,
#  210,
#  221,
#  164,
#  195,
#  181,
#  228,
#  178,
#  165,
#  140,
#  112,
#  130,
#  121,
#  107,
#  84,
#  83,
#  53,
#  80,
#  65,
#  58,
#  55,
#  30,
#  34,
#  29,
#  31,
#  28,
#  29,
#  14,
#  21,
#  24,
#  20,
#  14,
#  16,
#  15,
#  5,
#  6,
#  3,
#  7,
#  6,
#  4,
#  3,
#  3,
#  2,
#  0,
#  1,
#  1]

# %%
plt.figure()
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))

plt.barh(range(101),total,color='tomato')

plt.show()

# %% [markdown]
# ## barh 차트

# %%
plt.figure()
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

plt.title('{} 인구 구조'.format(name))


plt.show()

# %% [markdown]
# ## 진짜 우리동네 인구구조

# %% [markdown]
# # 우리동네 남여 구조

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0, thousands=',')
# 불필요한 데이터 삭제
#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']
name = '아름동'
mytown = df[df.index.str.contains(name)]
#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

#남자 음수로 반환
temp = male* -1

#시각화
plt.figure( figsize=(5,4))
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐
plt.title('{} 인구 구조'.format(name))
plt.barh(range(101),temp.iloc[0],label='남성')
plt.barh(range(101),female.iloc[0],label='여성')

plt.legend()
plt.show()

# %%
female.head()
# Out:
#                           여_0세  여_1세  여_2세  여_3세  여_4세  여_5세  여_6세  여_7세  \
# 행정구역
# 세종특별자치시  아름동(3611053000)    81   116   108   141   119   156   175   171
#
#                           여_8세  여_9세  ...  여_91세  여_92세  여_93세  여_94세  여_95세  \
# 행정구역                                  ...
# 세종특별자치시  아름동(3611053000)   173   225  ...      3      6      5      2      2
#
#                           여_96세  여_97세  여_98세  여_99세  여_100세 이상
# 행정구역
# 세종특별자치시  아름동(3611053000)      3      2      0      1          0
#
# [1 rows x 101 columns]

# %%
male.head()
# Out:
#                           남_0세  남_1세  남_2세  남_3세  남_4세  남_5세  남_6세  남_7세  \
# 행정구역
# 세종특별자치시  아름동(3611053000)    97   103    91   128   141   160   182   212
#
#                           남_8세  남_9세  ...  남_91세  남_92세  남_93세  남_94세  남_95세  \
# 행정구역                                  ...
# 세종특별자치시  아름동(3611053000)   213   203  ...      0      1      1      2      1
#
#                           남_96세  남_97세  남_98세  남_99세  남_100세 이상
# 행정구역
# 세종특별자치시  아름동(3611053000)      0      0      0      0          1
#
# [1 rows x 101 columns]

# %% [markdown]
# ## 모든 값 음수로 변환

# %% [markdown]
# > **[해석]**
# > *    ㅇㅇㅇ

# %% [markdown]
# ## 진짜 우리동네 남여 구조

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 행정구역을 index_col로 정하고 로드
df=pd.read_csv('./data/population_new.csv',index_col=0, thousands=',')
# 불필요한 데이터 삭제
#남_총인구수,남_연령구간인구수
#여_총인구수,여_연령구간인구수
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']
name = '명륜동'
mytown = df[df.index.str.contains(name)]
#남여 데이터 추출
male = mytown.iloc[:,0:101]
female = mytown.iloc[:,101:202]

#남자 음수로 반환
temp = male* -1

#시각화
plt.figure( figsize=(5,4))
# plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐
plt.title('{} 인구 구조'.format(name))
plt.barh(range(101),temp.iloc[0],label='남성')
plt.barh(range(101),female.iloc[0],label='여성')

plt.legend()
plt.show()

# %% [markdown]
# # 바람부는 제주에는 정말 여성의 비율이 높을까?

# %% [markdown]
# ## 데이터 로딩 및 전처리

# %%
from math import factorial
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

        
#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)]

m=mytown['남_총인구수'][0]
f=mytown['여_총인구수'][0]
m,f

## 중복데이터가 많이 나옴, 그중에서 0번째 데이터 사용할 것임
# Out:
# (340105, 338911)

# %% [markdown]
# ## pie 차트
# * 전체 데이터 중 특정 데이터의 비율을 보기 쉽게 표현합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 
         

#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)]

m = mytown['남_총인구수'][0]
f = mytown['여_총인구수'][0]
m,f
# Out:
# (340105, 338911)

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')

plt.pie([m,f], labels=['남성','여성'],autopct='%.1f%%',startangle=90,colors=['darkcyan','crimson'])# 소수점 한자리 까지 표현
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')

plt.title(f'{name} 남여 성별 비율')

plt.pie([m,f], labels=['남성','여성'],autopct='%.1f%%',startangle=90,colors=['darkcyan','crimson'])# 소수점 한자리 까지 표현
plt.show()

# %% [markdown]
# > **[해석]**
# > *   ㅋㅋㅋㅋ

# %% [markdown]
# ## line: 제주특별자치도 남여 인구 구조¶

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

# print(male.shape)


plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False

plt.title('{} 남여 인구 구조'.format(name))


plt.plot(range(101),male,label='남성')
plt.plot(range(101),female,label='여성')


plt.legend()
plt.show()

# %% [markdown]
# > * 항아리 모양 그래프보다 남녀 인구의 차이가 눈에 더 잘 들어옵니다.
# > * 좀 더 차이가 한 눈에 들어오도록 한다면?

# %% [markdown]
# ## bar:제주특별자치도 남여 인구 구조
#
# * 남자-여자를 뺀 값으로  막대그래프 그려봄

# %% [markdown]
# ### 데이터 로딩 및 전처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

female.index=female.index.str.replace('여_','')
male.index=male.index.str.replace('남_','')
print(male-female)



# 남자-여자 연산 실패 --> index값이 같이 않아서...
# Out:
# 0세         128
# 1세         145
# 2세         129
# 3세          66
# 4세         170
#           ...
# 96세       -127
# 97세        -99
# 98세        -62
# 99세       -204
# 100세 이상   -191
# Name: 제주특별자치도  (5000000000), Length: 101, dtype: int64

# %% [markdown]
# ### 남성에서 여성인구를 빼서 차이 정도를 시각화

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

#남-여 데이터 만들기
result = male.values - female.values 

plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False
plt.bar( )
plt.show()

plt.title('{} 남여 인구 구조'.format(name))

female.index=female.index.str.replace('여_','')
male.index=male.index.str.replace('남_','')
print(male-female)
# Out:
# 0세         128
# 1세         145
# 2세         129
# 3세          66
# 4세         170
#           ...
# 96세       -127
# 97세        -99
# 98세        -62
# 99세       -204
# 100세 이상   -191
# Name: 제주특별자치도  (5000000000), Length: 101, dtype: int64

# %% [markdown]
# > * 60대를 기준으로 그 이하의 연령대는 남성이 많지만,
# > * 60대 이상 인구는 여성이 많다는 것이 확연히 드러납니다.

# %% [markdown]
# ## scatter 차트
#
# * 데이터의 관계를 파악하는 데 도움이 되는 산점도 그래프입니다.
# * 산점도는 가로축과 세로축을 기준으로 두 요소가 서로 어떤 관계를 맺고 있는지를 파악하기 쉽게 나타낸 그래프입니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/population_new.csv',index_col=0, thousands = ',') # 컬럼0번째를 index_column으로 설정 

# 불필요한 데이터 삭제
del df['남_총인구수'], df['남_연령구간인구수']
del df['여_총인구수'], df['여_연령구간인구수']


#우리동네 데이터 추출
name = '제주특별자치도'
mytown = df[df.index.str.contains(name)] # 공백 데이터 처리

#남여 데이터 추출
male = mytown.iloc[0,0:101]
female = mytown.iloc[0,101:202]

#우리동네 연령별 총 인구수
total = []

for i in range(0,101):
    # print(mytown.iloc[0,i])
    total.append(mytown.iloc[0,i] + mytown.iloc[0,i+101])

# %%
plt.figure(figsize=(6,4))
plt.style.use('ggplot')
plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus']=False

plt.title('{} 남여 인구 구조'.format(name))


plt.scatter(male,female)
plt.show()

# %%
plt.scatter(male,female,c=range(101),s=total)#101개 의 데이터를 각각 다른 컬러로 표현
plt.show()

# %%
import math

size = []

for i in range(101):
    #print(i)
    #print(math.sqrt(total[i]))
    size.append(math.sqrt(total[i]))

# %%
size[:5]
# Out:
# [59.51470406546604,
#  62.617888817813075,
#  66.29479617586888,
#  69.74238309665078,
#  73.56629663099808]

# %%
plt.scatter(male,female,c=range(101),s=size,alpha=0.5,cmap='jet') #데이터 포인트의 크기 조절(sqrt(인구의 총합))
plt.show()

# %%
plt.scatter(male,female,c=range(101),s=size,alpha=0.5,cmap='jet') #컬러맵

plt.plot(range(max(male)), range(max(male))) #추세선 넣기 y=x형태로
plt.show()
