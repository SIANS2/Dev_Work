# %% [markdown]
# # 서울의 기온 데이터 분석
#
# * https://data.kma.go.kr/stcs/grnd/grndTaList.do?pgmNo=70
#
# * 기온분석>
#     * 자료구분:일,
#     * 자료형태:기본,
#     * 기간: ~ 현재,
#     * 지역: 서울
# * CSV 파일 형태로 다운

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ### 데이터에 대한 질문
#
# * 서울이 가장 더웠던 날은 언제였을까? 얼마나 더웠을까?
# * 일교차가 가장 큰 시기는 1년 중 언제쯤일까?
# * 겨울에는 언제 가장 추울까? 12월? 1월? 2월?
# * 가장 덥다고 알려진 대구보다 서울이 더 더운 날이 1년 중 얼마나 있을까?

# %% [markdown]
# ## 라이브러리 로드

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\sian\appdata\roaming\python\python39\site-packages (3.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (4.37.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sian\appdata\roaming\python\python39\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\sian\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# 라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# #코랩의 경우
# # 나눔고딕 폰트 인스톨
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ## 데이터 로드

# %%
# 데이터 로드, 인"코딩, header,sep 등 필요한 파라미터 사용
df = pd.read_csv('./data/ta_20220920103942.csv', header=6) # 불러드릴 row위치 지정
df.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %% [markdown]
# > * 인코딩 에러 -> 편집기에서 인코딩(utf-8)로 명시적으로 지정 후, 저장해서 다시 판다스로 로드
# > * Parse 에러(메모장사용시) -> 데이터의 윗부분의 텍스트를 로드할 때 해석하지 못하는 문자열이 있어서  에러발생-> header=6
# > * UTF-8로 변환시 사용했던 편집기에 따라 상의한 결과-> header 숫자를 적절하게 조정
#
# > * 보통 한글에서 사용하는 인코딩 종류(utf-8, euc-kr, cp949, utf-8-sig)

# %%
# 데이터 로드, 인코딩, header,sep 등 필요한 파라미터 사용
df = pd.read_csv('./data/ta_20220920103942.csv', header=6, encoding='euc-kr') # default: utf-8,
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [17], line 2
#       1 # 데이터 로드, 인코딩, header,sep 등 필요한 파라미터 사용
# ----> 2 df = pd.read_csv('./data/ta_20220920103942.csv', header=6, encoding='euc-kr') # default: utf-8,
#       3 df.head()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:1234, in TextFileReader._make_engine(self, f, engine)
#    1231     raise ValueError(msg)
#    1233 try:
# -> 1234     return mapping[engine](f, **self.options)
#    1235 except Exception:
#    1236     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'euc_kr' codec can't decode byte 0x98 in position 4: illegal multibyte sequence

# %% [markdown]
# ## 데이터 살펴보기
#
# * 데이터 사이즈 (행수, 컬럼수)
# * 컬럼 이름과 타입
# * 결측치 유무
# * 통계정보

# %%
df.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41562 entries, 0 to 41561
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       41562 non-null  object
#  1   지점       41562 non-null  int64
#  2   평균기온(℃)  40806 non-null  float64
#  3   최저기온(℃)  40803 non-null  float64
#  4   최고기온(℃)  40803 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# > * 데이터수: 41562건
# > * 컬럼수와 이름: 5개
# > * 컬럼 타임: 날짜-> str, 기온: 실수
# > * 결측치 유무: 기온 컬럼에 대해서는 결측치 존재 -> 어떻게?

# %%
df.describe() # 숫자형 컬럼에만 국한
# Out:
#             지점       평균기온(℃)       최저기온(℃)       최고기온(℃)
# count  41562.0  40806.000000  40803.000000  40803.000000
# mean     108.0     11.781135      7.490523     16.784746
# std        0.0     10.662868     10.891121     10.980128
# min      108.0    -19.200000    -23.100000    -16.300000
# 25%      108.0      2.725000     -1.400000      7.300000
# 50%      108.0     13.000000      8.000000     18.600000
# 75%      108.0     21.200000     17.200000     26.300000
# max      108.0     33.700000     30.300000     39.600000

# %% [markdown]
# ## 결측 데이터 전처리

# %% [markdown]
# ### 결측데이터수 파악하기

# %%
df.isnull().sum()
# Out:
# 날짜           0
# 지점           0
# 평균기온(℃)    756
# 최저기온(℃)    759
# 최고기온(℃)    759
# dtype: int64

# %% [markdown]
# ### 평균기온, 최저기온, 최고 기온 결측치인 날짜 찾음

# %%
df['평균기온(℃)'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41557    False
# 41558    False
# 41559    False
# 41560    False
# 41561    False
# Name: 평균기온(℃), Length: 41562, dtype: bool

# %%
# 평균기온, 최저기온, 최고 기온의 결측치인 날짜 찾음
df[df['평균기온(℃)'].isnull()]
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 15676  1950-09-01  108      NaN      NaN      NaN
# 15677  1950-09-02  108      NaN      NaN      NaN
# 15678  1950-09-03  108      NaN      NaN      NaN
# 15679  1950-09-04  108      NaN      NaN      NaN
# 15680  1950-09-05  108      NaN      NaN      NaN
# ...           ...  ...      ...      ...      ...
# 16427  1953-11-26  108      NaN      NaN      NaN
# 16428  1953-11-27  108      NaN      NaN      NaN
# 16429  1953-11-28  108      NaN      NaN      NaN
# 16430  1953-11-29  108      NaN      NaN      NaN
# 16431  1953-11-30  108      NaN      NaN      NaN
#
# [756 rows x 5 columns]

# %% [markdown]
# > * 1950년대에는 전쟁중이어서 관측 불가

# %%
df[df['최저기온(℃)'].isnull()]
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 15676  1950-09-01  108      NaN      NaN      NaN
# 15677  1950-09-02  108      NaN      NaN      NaN
# 15678  1950-09-03  108      NaN      NaN      NaN
# 15679  1950-09-04  108      NaN      NaN      NaN
# 15680  1950-09-05  108      NaN      NaN      NaN
# ...           ...  ...      ...      ...      ...
# 16430  1953-11-29  108      NaN      NaN      NaN
# 16431  1953-11-30  108      NaN      NaN      NaN
# 21260  1967-02-19  108     -1.7      NaN      NaN
# 23691  1973-10-16  108     12.3      NaN      NaN
# 41519  2022-08-08  108     26.8      NaN     28.4
#
# [759 rows x 5 columns]

# %%
# 2017년에도 결측치 있네...
df[df['최고기온(℃)'].isnull()]
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 15676  1950-09-01  108      NaN      NaN      NaN
# 15677  1950-09-02  108      NaN      NaN      NaN
# 15678  1950-09-03  108      NaN      NaN      NaN
# 15679  1950-09-04  108      NaN      NaN      NaN
# 15680  1950-09-05  108      NaN      NaN      NaN
# ...           ...  ...      ...      ...      ...
# 16430  1953-11-29  108      NaN      NaN      NaN
# 16431  1953-11-30  108      NaN      NaN      NaN
# 21260  1967-02-19  108     -1.7      NaN      NaN
# 23691  1973-10-16  108     12.3      NaN      NaN
# 39758  2017-10-12  108     11.4      8.8      NaN
#
# [759 rows x 5 columns]

# %% [markdown]
# ### 결측치 데이터 처리
# * 분석 목적과 도메인의 영향이 큼

# %%
# 평균기온은 0, 최저기온은 999, 최고기온은 -999로 채움

df['평균기온(℃)'] = df['평균기온(℃)'].fillna(0)
df['최저기온(℃)'] = df['최저기온(℃)'].fillna(999)
df['최고기온(℃)'] = df['최고기온(℃)'].fillna(-999)

# %%
df.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41562 entries, 0 to 41561
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       41562 non-null  object
#  1   지점       41562 non-null  int64
#  2   평균기온(℃)  41562 non-null  float64
#  3   최저기온(℃)  41562 non-null  float64
#  4   최고기온(℃)  41562 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df['날짜'].str.contains('1950')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41557    False
# 41558    False
# 41559    False
# 41560    False
# 41561    False
# Name: 날짜, Length: 41562, dtype: bool

# %%
#결측치였던 1950년대 데이터가 어떻게 바뀌었는지 확인
df[ df['날짜'].str.contains('1950') ]
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 15433  1950-01-01  108      2.8      0.7      4.5
# 15434  1950-01-02  108     -0.1     -3.8      2.4
# 15435  1950-01-03  108     -4.6     -7.3     -0.7
# 15436  1950-01-04  108     -7.7    -11.2     -4.2
# 15437  1950-01-05  108     -7.0    -11.6     -3.1
# ...           ...  ...      ...      ...      ...
# 15727  1950-10-27  108      0.0    999.0   -999.0
# 15728  1950-10-28  108      0.0    999.0   -999.0
# 15729  1950-10-29  108      0.0    999.0   -999.0
# 15730  1950-10-30  108      0.0    999.0   -999.0
# 15731  1950-10-31  108      0.0    999.0   -999.0
#
# [299 rows x 5 columns]

# %%
df[(df['최저기온(℃)']==-999)| (df['최고기온(℃)']==999) | (df['평균기온(℃)']==0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '최저기온(℃)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [67], line 1
# ----> 1 df[(df['최저기온(℃)']==-999)| (df['최고기온(℃)']==999) | (df['평균기온(℃)']==0)]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: '최저기온(℃)'

# %% [markdown]
# ## 컬럼명 바꾸기

# %%
df.columns
# Out:
# Index(['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)'], dtype='object')

# %%
df.rename(columns={df.columns[2]:'평균기온',
                   df.columns[3]:'최저기온', 
                   df.columns[4]:'최고기온'}, inplace=True)

# %%
df.head()
# Out:
#            날짜   지점  평균기온  최저기온  최고기온
# 0  1907-10-01  108  13.5   7.9  20.7
# 1  1907-10-02  108  16.2   7.9  22.0
# 2  1907-10-03  108  16.2  13.1  21.3
# 3  1907-10-04  108  16.5  11.2  22.0
# 4  1907-10-05  108  17.6  10.9  25.4

# %% [markdown]
# ## 서울에서 가장 더웠던 날은?

# %%
#최고 더운 날은?
df.sort_values(by=['최고기온'],ascending=False)
# Out:
#                날짜   지점  평균기온   최저기온   최고기온
# 40051  2018-08-01  108  33.6   27.8   39.6
# 31277  1994-07-24  108  33.1   28.1   38.4
# 40050  2018-07-31  108  32.6   27.8   38.3
# 13111  1943-08-24  108  29.0   23.2   38.2
# 31276  1994-07-23  108  32.6   28.0   38.2
# ...           ...  ...   ...    ...    ...
# 16069  1952-12-03  108   0.0  999.0 -999.0
# 15869  1952-04-16  108   0.0  999.0 -999.0
# 15909  1952-05-26  108   0.0  999.0 -999.0
# 16070  1952-12-04  108   0.0  999.0 -999.0
# 16362  1953-09-22  108   0.0  999.0 -999.0
#
# [41562 rows x 5 columns]

# %%
# 서울에서 가장 더웠던 날은? 2018-08-01: 39.6도 출력
df_temp = df.sort_values(by=['최고기온'], ascending=False)
df_temp.iloc[:1,[0,4]]
# Out:
#                날짜  최고기온
# 40051  2018-08-01  39.6

# %%
df.sort_values(by=['최고기온'],ascending=False,).head(1)
# Out:
#                날짜   지점  평균기온  최저기온  최고기온
# 40051  2018-08-01  108  33.6  27.8  39.6

# %%
df[['날짜','최고기온']].max() # 날짜의 최고, 최고기온의 최고를 추출하는 것임.
# Out:
# 날짜      2022-09-19
# 최고기온          39.6
# dtype: object

# %%
df[df['최고기온']==df['최고기온'].max()]
# Out:
#                날짜   지점  평균기온  최저기온  최고기온
# 40051  2018-08-01  108  33.6  27.8  39.6

# %%
df.loc[40051,'날짜']
# Out:
# '2018-08-01'

# %%
# 서울에서 가장 더웠던 날은? 2018-08-01: 39.6도 출력
df_date = df.loc[40051,"날짜"]
df_deg = df.loc[40051,"최고기온"]

print("서울에서 가장 더웠던 날은? {0}: {1} 도".format(df_date,df_deg))
# Out:
# 서울에서 가장 더웠던 날은? 2018-08-01: 39.6 도

# %% [markdown]
# # 내 생일날 기온변화 그래프 그리기

# %% [markdown]
# ## 내 생일날 기온변화 그래프 그리기(평균기온 기준)
# * 데이터 로딩
# * 결측 데이터 전처리
# * 내 생일 데이터만 추출
# * 필요한 컬럼만 추출 or 불필요한 데이터 삭제
# * 그래프 그리기

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 데이터 로딩
df = pd.read_csv('./data/ta_20220920103942.csv', header=6) # 불러드릴 row위치 지정
df.head()

# 결측치 처리
df['평균기온(℃)'] = df['평균기온(℃)'].fillna(0)
df['최저기온(℃)'] = df['최저기온(℃)'].fillna(999)
df['최고기온(℃)'] = df['최고기온(℃)'].fillna(-999)

# 데이터 전처리(컬럼명 수정)
df.rename(columns={df.columns[2]:'평균기온',
                   df.columns[3]:'최저기온', 
                   df.columns[4]:'최고기온'}, inplace=True)

# %%
df.head()
# Out:
#            날짜   지점  평균기온  최저기온  최고기온
# 0  1907-10-01  108  13.5   7.9  20.7
# 1  1907-10-02  108  16.2   7.9  22.0
# 2  1907-10-03  108  16.2  13.1  21.3
# 3  1907-10-04  108  16.5  11.2  22.0
# 4  1907-10-05  108  17.6  10.9  25.4

# %% [markdown]
# ## 내 생일 데이터만 추출

# %%
# 어떤 컬럼을 기준으로 내생일 기온그래프를 그릴껀지 고민
# 내 생일 데이터만 추출 (06-14)

df['날짜'].str.contains('12-17')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41557    False
# 41558    False
# 41559    False
# 41560    False
# 41561    False
# Name: 날짜, Length: 41562, dtype: bool

# %%
birth_df = df[df['날짜'].str.contains('12-17')]

# %%
birth_df.head()
# Out:
#               날짜   지점  평균기온  최저기온  최고기온
# 77    1907-12-17  108  -7.3 -13.2  -2.1
# 443   1908-12-17  108   0.8  -6.1   6.3
# 808   1909-12-17  108  -5.7 -12.9  -0.8
# 1173  1910-12-17  108  -5.5 -12.6   1.1
# 1538  1911-12-17  108  -3.9 -11.0   2.8

# %% [markdown]
# ## 필요한 컬럼만 추출

# %%
# 필요한 컬럼만 추출 (날짜, 평균기온)

birth_df = birth_df[['날짜','평균기온']]

# %%
birth_df.head()
# Out:
#               날짜  평균기온
# 77    1907-12-17  -7.3
# 443   1908-12-17   0.8
# 808   1909-12-17  -5.7
# 1173  1910-12-17  -5.5
# 1538  1911-12-17  -3.9

# %%
# 내 생일 데이터 그래프 그리기
import matplotlib.pyplot as pit
plt.plot(birth_df['날짜'],birth_df['평균기온'])

# %%
birth_df['평균기온']<5
# Out:
# 77        True
# 443       True
# 808       True
# 1173      True
# 1538      True
#          ...
# 39824     True
# 40189     True
# 40554    False
# 40920     True
# 41285     True
# Name: 평균기온, Length: 114, dtype: bool

# %%
birth_df[birth_df['평균기온']==0]
# Out:
#                날짜  평균기온
# 15748  1951-12-17   0.0
# 16083  1952-12-17   0.0

# %% [markdown]
# >*결측치를 잘 못 처리 한 것 같습니다. 0도로 일괄 처리한 부분이 문제로 보임

# %% [markdown]
# ## 결측 데이터 재 처리

# %% [markdown]
# > * 평균 기온이 0인 데이터 어떻게 처리 할 것인가?
# > * 결측치를 삭제하는 것으로 처리

# %%
#라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 데이터 로딩
df = pd.read_csv('./data/ta_20220920103942.csv', header=6) # 불러드릴 row위치 지정
df.head()


# 데이터 전처리(컬럼명 수정)
df.rename(columns={df.columns[2]:'평균기온',
                   df.columns[3]:'최저기온', 
                   df.columns[4]:'최고기온'}, inplace=True)

# %%
# 결측 데이터 삭제

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 날짜      0
# 지점      0
# 평균기온    0
# 최저기온    0
# 최고기온    0
# dtype: int64

# %%
birth_df = df[df['날짜'].str.contains('12-17')]
birth_df = birth_df[['날짜','평균기온']]
import matplotlib.pyplot as pit
plt.plot(birth_df['날짜'],birth_df['평균기온'])

# %% [markdown]
# ## 내가 태어난 이 후의 데이터만 추출해서 살펴보기

# %%
birth_df [( df['날짜'].str.contains('06-14')) & (df['날짜'] >= '1980-01-01')]
birth_df.head()
# Out:
# C:\Users\sian\AppData\Local\Temp\ipykernel_21980\1095795936.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   birth_df [( df['날짜'].str.contains('06-14')) & (df['날짜'] >= '1980-01-01')]
#               날짜  평균기온
# 77    1907-12-17  -7.3
# 443   1908-12-17   0.8
# 808   1909-12-17  -5.7
# 1173  1910-12-17  -5.5
# 1538  1911-12-17  -3.9

# %%
# 내 생일이면서, 1980년 이후의 데이터만 추출
#[birth_df['평균기온'] >= '1980-01-01'] 
birth_df = df[df['날짜'].str.contains('12-17')]
birth_df[birth_df['날짜']>='1980-01-01']

birth_df.head()
# Out:
#               날짜   지점  평균기온  최저기온  최고기온
# 77    1907-12-17  108  -7.3 -13.2  -2.1
# 443   1908-12-17  108   0.8  -6.1   6.3
# 808   1909-12-17  108  -5.7 -12.9  -0.8
# 1173  1910-12-17  108  -5.5 -12.6   1.1
# 1538  1911-12-17  108  -3.9 -11.0   2.8

# %%
# 필요한 컬럼만 추출
birth_df = df[df['날짜'].str.contains('12-17')]
birth_df[birth_df['날짜']>='1980-01-01']
# Out:
#                날짜   지점  평균기온  최저기온  최고기온
# 26310  1980-12-17  108  -2.1  -6.7   3.2
# 26675  1981-12-17  108  -1.0  -5.7   4.2
# 27040  1982-12-17  108  -4.0  -7.3   0.4
# 27405  1983-12-17  108  -5.1  -7.1  -2.5
# 27771  1984-12-17  108   0.1  -2.6   3.8
# 28136  1985-12-17  108  -9.4 -12.9  -5.0
# 28501  1986-12-17  108   4.4  -1.1   8.9
# 28866  1987-12-17  108   2.2  -0.3   5.2
# 29232  1988-12-17  108  -3.5  -8.5   1.5
# 29597  1989-12-17  108   4.8   1.8   8.3
# 29962  1990-12-17  108  -0.4  -3.3   1.9
# 30327  1991-12-17  108   6.4   1.8   8.8
# 30693  1992-12-17  108  -0.2  -4.1   3.7
# 31058  1993-12-17  108  -7.2  -9.4  -4.4
# 31423  1994-12-17  108  -5.6  -8.7  -1.9
# 31788  1995-12-17  108  -1.5  -4.4   1.9
# 32154  1996-12-17  108   5.0  -3.6   8.0
# 32519  1997-12-17  108   4.8   1.6   7.5
# 32884  1998-12-17  108   6.0   1.9  11.8
# 33249  1999-12-17  108  -3.8  -6.4  -0.8
# 33615  2000-12-17  108  -0.5  -4.8   4.1
# 33980  2001-12-17  108  -2.6  -6.8   1.3
# 34345  2002-12-17  108   2.6   1.1   6.0
# 34710  2003-12-17  108  -0.7  -4.4   3.7
# 35076  2004-12-17  108   3.8   0.8   7.5
# 35441  2005-12-17  108  -9.7 -13.3  -5.8
# 35806  2006-12-17  108  -1.0  -3.9   1.6
# 36171  2007-12-17  108   2.3  -0.4   5.9
# 36537  2008-12-17  108   6.4   1.5   9.3
# 36902  2009-12-17  108  -7.2 -10.2  -3.2
# 37267  2010-12-17  108  -2.1  -5.5   2.6
# 37632  2011-12-17  108  -5.8 -10.6  -1.6
# 37998  2012-12-17  108  -0.4  -4.7   3.2
# 38363  2013-12-17  108  -0.3  -5.5   4.7
# 38728  2014-12-17  108  -9.0 -11.1  -5.2
# 39093  2015-12-17  108  -4.6  -7.4  -0.4
# 39459  2016-12-17  108   2.7  -2.7   8.0
# 39824  2017-12-17  108  -6.7 -10.8  -2.3
# 40189  2018-12-17  108   1.6  -1.5   5.9
# 40554  2019-12-17  108   7.7   3.2  10.2
# 40920  2020-12-17  108  -4.9 -11.1   0.8
# 41285  2021-12-17  108  -5.6 -10.1   3.2

# %%
# 내 생일 데이터 그래프 그리기
import matplotlib.pyplot as pit
plt.plot(birth_df['날짜'],birth_df['평균기온'])

# %% [markdown]
# ## 내가 태어난 날 -> 날짜 형식으로 변환하고 데이터 추출하고 보기

# %% [markdown]
# ### 날짜 컬럼 Dtype 확인

# %%
# 날짜 컬럼 타입 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40801 entries, 0 to 41560
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   1907-10-01  40801 non-null  object
#  1   108         40801 non-null  int64
#  2   평균기온        40801 non-null  float64
#  3   최저기온        40801 non-null  float64
#  4   최고기온        40801 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# ### object -> datetime64[ns] 형변환

# %%
# 날짜 데이터 Str => date 형으로 변환
df['날짜'] =df['날짜'].astype('datetime64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41562 entries, 0 to 41561
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      41562 non-null  datetime64[ns]
#  1   지점      41562 non-null  int64
#  2   평균기온    41562 non-null  float64
#  3   최저기온    41562 non-null  float64
#  4   최고기온    41562 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 1.6 MB

# %%
df['날짜'].dt.year
# Out:
# 0        1907
# 1        1907
# 2        1907
# 3        1907
# 4        1907
#          ...
# 41557    2022
# 41558    2022
# 41559    2022
# 41560    2022
# 41561    2022
# Name: 날짜, Length: 41562, dtype: int64

# %%
df.head()
# Out:
#           날짜   지점  평균기온  최저기온  최고기온
# 0 1907-10-01  108  13.5   7.9  20.7
# 1 1907-10-02  108  16.2   7.9  22.0
# 2 1907-10-03  108  16.2  13.1  21.3
# 3 1907-10-04  108  16.5  11.2  22.0
# 4 1907-10-05  108  17.6  10.9  25.4

# %%
df['년'] = df['날짜'].dt.year
df['월'] = df['날짜'].dt.month
df['일'] = df['날짜'].dt.day

# %%
df.head()
# Out:
#           날짜   지점  평균기온  최저기온  최고기온     년   월  일
# 0 1907-10-01  108  13.5   7.9  20.7  1907  10  1
# 1 1907-10-02  108  16.2   7.9  22.0  1907  10  2
# 2 1907-10-03  108  16.2  13.1  21.3  1907  10  3
# 3 1907-10-04  108  16.5  11.2  22.0  1907  10  4
# 4 1907-10-05  108  17.6  10.9  25.4  1907  10  5

# %% [markdown]
# ### 내 생일이면서 1980년 이후의 데이터만 추출

# %%
birth_df = df[(df['월'] == 6) & (df['일'] ==14)]
birth_df[birth_df['날짜'] >= '1980-01-01']
# Out:
#               날짜   지점  평균기온  최저기온  최고기온     년  월   일
# 26124 1980-06-14  108  25.5  19.1  31.6  1980  6  14
# 26489 1981-06-14  108  22.5  16.9  27.8  1981  6  14
# 26854 1982-06-14  108  22.0  16.7  27.6  1982  6  14
# 27219 1983-06-14  108  22.3  17.3  29.6  1983  6  14
# 27585 1984-06-14  108  26.9  21.1  31.9  1984  6  14
# 27950 1985-06-14  108  19.8  14.4  24.7  1985  6  14
# 28315 1986-06-14  108  22.0  18.9  25.2  1986  6  14
# 28680 1987-06-14  108  21.1  17.3  26.1  1987  6  14
# 29046 1988-06-14  108  23.4  18.6  28.6  1988  6  14
# 29411 1989-06-14  108  19.8  16.2  23.9  1989  6  14
# 29776 1990-06-14  108  22.6  20.5  25.4  1990  6  14
# 30141 1991-06-14  108  23.5  17.0  30.0  1991  6  14
# 30507 1992-06-14  108  21.1  15.5  26.6  1992  6  14
# 30872 1993-06-14  108  21.4  20.3  23.4  1993  6  14
# 31237 1994-06-14  108  25.7  19.7  32.7  1994  6  14
# 31602 1995-06-14  108  22.3  16.4  27.0  1995  6  14
# 31968 1996-06-14  108  22.6  20.2  26.4  1996  6  14
# 32333 1997-06-14  108  25.8  19.7  32.1  1997  6  14
# 32698 1998-06-14  108  20.6  15.8  26.9  1998  6  14
# 33063 1999-06-14  108  25.1  18.5  32.0  1999  6  14
# 33429 2000-06-14  108  24.4  19.3  29.7  2000  6  14
# 33794 2001-06-14  108  22.5  18.6  27.4  2001  6  14
# 34159 2002-06-14  108  20.4  16.4  25.0  2002  6  14
# 34524 2003-06-14  108  20.2  18.6  22.7  2003  6  14
# 34890 2004-06-14  108  23.6  18.2  29.0  2004  6  14
# 35255 2005-06-14  108  24.1  20.3  31.8  2005  6  14
# 35620 2006-06-14  108  19.0  16.5  22.1  2006  6  14
# 35985 2007-06-14  108  23.4  19.8  28.5  2007  6  14
# 36351 2008-06-14  108  23.9  19.2  28.9  2008  6  14
# 36716 2009-06-14  108  20.4  18.4  23.5  2009  6  14
# 37081 2010-06-14  108  22.8  20.0  26.4  2010  6  14
# 37446 2011-06-14  108  22.8  16.8  29.5  2011  6  14
# 37812 2012-06-14  108  24.8  19.3  31.7  2012  6  14
# 38177 2013-06-14  108  24.6  20.9  29.7  2013  6  14
# 38542 2014-06-14  108  22.5  18.3  27.7  2014  6  14
# 38907 2015-06-14  108  22.8  17.8  27.7  2015  6  14
# 39273 2016-06-14  108  23.8  19.7  29.5  2016  6  14
# 39638 2017-06-14  108  21.8  17.8  26.8  2017  6  14
# 40003 2018-06-14  108  21.6  18.8  25.1  2018  6  14
# 40368 2019-06-14  108  23.0  19.1  28.4  2019  6  14
# 40734 2020-06-14  108  24.0  20.1  28.8  2020  6  14
# 41099 2021-06-14  108  24.8  18.9  30.2  2021  6  14
# 41464 2022-06-14  108  21.5  17.7  27.1  2022  6  14

# %%
# 내 생일이면서, 1980년 이후의 데이터만 추출
birth2_df = birth_df[birth_df['날짜'] >= '1980-01-01']
birth2_df.head()
# Out:
#                날짜   지점  평균기온  최저기온  최고기온
# 26310  1980-12-17  108  -2.1  -6.7   3.2
# 26675  1981-12-17  108  -1.0  -5.7   4.2
# 27040  1982-12-17  108  -4.0  -7.3   0.4
# 27405  1983-12-17  108  -5.1  -7.1  -2.5
# 27771  1984-12-17  108   0.1  -2.6   3.8

# %% [markdown]
# ## 그래프 그리기

# %%
# 내 생일 데이터 그래프 그리기

plt.plot(birth_df['년'],birth_df['평균기온'], color='tomato')
plt.title('06-14 Seoul Temperature')
plt.xlabel('date', loc='right')
plt.ylabel('average temperature (℃)', loc='top')
# Out:
# Text(0, 1, 'average temperature (℃)')

# %%
# X축에 날짜가 나오도록해서 다시 출력

# %% [markdown]
# # 매년 크리스마스의 최고 기온과 최저 기온의 추이를 그려보자.

# %% [markdown]
# # 같은 데이타, 다른 그래프, 새로운 분석
# * 서울 최고 기온 데이터 전체를 나타낸 lineplot을 보고 어떤 정보를 얻었나요?

# %% [markdown]
# ##  line:서울 최고 기온 그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/ta_20210103160419.csv',header=7)
df.rename(columns={
    df.columns[2]: '평균기온',
    df.columns[3]: '최저기온',
    df.columns[4]: '최고기온'
},inplace=True)

plt.plot(df['최고기온'])
plt.show()

# %% [markdown]
# > * 최고 기온 데이터 전체를 그래프로 나타냈는데, 결측치 존재 말고는 특별한 정보를 얻을 수 없습니다.
# > * 다른 관점으로 데이터를 바라보기 위해서
# > * 다른 종류의 시각화를 시도해 봅시다.

# %% [markdown]
# ## hist:기온 데이터를 히스토그램으로 표현하기
#
# * 특정구간의 자료의 수를 표현할때

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('./data/ta_20220920103942.csv',header=7)
df.rename(columns={
    df.columns[2]: '평균기온',
    df.columns[3]: '최저기온',
    df.columns[4]: '최고기온'
},inplace=True)

# %%
pit.hist(df['최고기온'])
# Out:
# (array([  35.,  596., 2812., 5465., 5275., 4915., 6247., 9003., 5915.,
#          538.]),
#  array([-16.3 , -10.71,  -5.12,   0.47,   6.06,  11.65,  17.24,  22.83,
#          28.42,  34.01,  39.6 ]),
#  <BarContainer object of 10 artists>)

# %%
# pandas 내부의 매플랏립 라이브러리와 연동
df['최고기온'].hist(bins=1000) #20구간으로 나눠서 시각화
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## hist:겨울과 여름 계절의 패턴인가? 그럼 8월만 데이터를 뽑아보자.
# * 역대 8월의 최고 온도는?
# * 최고 기온의 분포(최저 ~ 최고)는?

# %%
df.head()
# Out:
#    1907-10-01  108  평균기온  최저기온  최고기온
# 0  1907-10-02  108  16.2   7.9  22.0
# 1  1907-10-03  108  16.2  13.1  21.3
# 2  1907-10-04  108  16.5  11.2  22.0
# 3  1907-10-05  108  17.6  10.9  25.4
# 4  1907-10-06  108  13.0  11.2  21.3

# %%
#결측치 삭제
df.dropna(inplace=True)
#날짜 타입으로 변환
df['날짜'].astype('datetime64')
#8월만 데이터 추출

df[df['날짜'].dt.month == 8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '날짜'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [52], line 4
#       2 df.dropna(inplace=True)
#       3 #날짜 타입으로 변환
# ----> 4 df['날짜'].astype('datetime64')
#       5 #8월만 데이터 추출
#       7 df[df['날짜'].dt.month == 8]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: '날짜'

# %%
#8월만 데이터 추출
aug_df=df[df['날짜'].dt.month == 8]
jan_df=df[df['날짜'].dt.month == 1]

# %% [markdown]
# ## hist:1월과 8월의 데이터를 히스토그램으로 시각화하기

# %%
# hist(데이터,몇개구간,색깔)

plt.hist(aug_df['최고기온'],bins=120,color='r',label='Aug')

plt.hist(jan_df['최고기온'],bins=120,color='b',label='Jan')

plt.legend() #범례표시
plt.show()

# %%
# 8월 데이터만 추출
aug_df=df[df['날짜'].dt.month == 8]

# 1월 데이터만 추출
jan_df=df[df['날짜'].dt.month == 1]

# %%
plt.hist(aug_df['최고기온'],bins=100,color='cyan')
plt.hist(jan_df['최고기온'],bins=100,color='salmon')
plt.show()

# %% [markdown]
# > * 같은 데이터에서 어떤 내용을 추출하여, 어떤 방법으로 시각화하는냐에 따라 새로운 정보를 발견할 수 있습니다.
# > * 1,8월 이외에 궁금한 달이 있다면 도전!

# %% [markdown]
# ## box:기온 데이터 대략적인 통계정보 확인하기

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/ta_20220920103942.csv',header=7)
df.rename(columns={
    df.columns[2]: '평균기온',
    df.columns[3]: '최저기온',
    df.columns[4]: '최고기온'
},inplace=True)


# 결측 데이터 삭제
df.dropna(inplace=True)

# %%
plt.boxplot(df['최고기온'])
plt.show()

# %%
plt.boxplot(df['최고기온'])
plt.boxplot(df['최저기온'])
plt.show()

# %%
df['최고기온'].describe()#2040944
# Out:
# count    40801.000000
# mean        16.784366
# std         10.980230
# min        -16.300000
# 25%          7.300000
# 50%         18.600000
# 75%         26.300000
# max         39.600000
# Name: 최고기온, dtype: float64

# %%
plt.rc('font',family='Malgun Gothic')   #윈도우 코렙

plt.rcParams['axes.unicode_minus']=False  #마이너스 기호 깨짐 방지

plt.boxplot([df['최고기온'], df['최저기온']], labels=['최고', '최저'] )
plt.show()

# %% [markdown]
# ## 월별 기온 데이터
#
# 1. 데이터를 월별로 조회하고, 결과를 리스트에 담는다.
# 2. 월별 데이터를 box plot으로 그래프 그린다.

# %%
df.head()
# Out:
#    1907-10-01  108  평균기온  최저기온  최고기온
# 0  1907-10-02  108  16.2   7.9  22.0
# 1  1907-10-03  108  16.2  13.1  21.3
# 2  1907-10-04  108  16.5  11.2  22.0
# 3  1907-10-05  108  17.6  10.9  25.4
# 4  1907-10-06  108  13.0  11.2  21.3

# %%
df = pd.read_csv('./data/ta_20220920103942.csv',header=6)
df.rename(columns={
    df.columns[2]: '평균기온',
    df.columns[3]: '최저기온',
    df.columns[4]: '최고기온'
},inplace=True)

# 결측 데이터 삭제
df.dropna(inplace=True)
# 날짜 데이터 Str => date 형으로 변환
df['날짜'] = df['날짜'].astype('datetime64')

# %%
#데이터를 월별로 조회
target_day = 1 
df.query('날짜.dt.day == @target_day')
# Out:
#               날짜   지점  평균기온  최저기온  최고기온   월
# 0     1907-10-01  108  13.5   7.9  20.7  10
# 31    1907-11-01  108  16.1  11.7  21.3  11
# 61    1907-12-01  108  -4.6 -10.5   1.4  12
# 92    1908-01-01  108  -5.9  -9.1  -1.3   1
# 123   1908-02-01  108  -2.2  -6.4   1.6   2
# ...          ...  ...   ...   ...   ...  ..
# 41420 2022-05-01  108  13.4   7.9  19.2   5
# 41451 2022-06-01  108  22.1  16.2  28.6   6
# 41481 2022-07-01  108  26.6  21.9  30.9   7
# 41512 2022-08-01  108  28.6  25.4  32.4   8
# 41543 2022-09-01  108  24.0  18.3  30.4   9
#
# [1341 rows x 6 columns]

# %%
df_month = df.values.tolist()
df_month = df.to_dict('list')

# %%
plt.boxplot(df_month['평균기온'])
plt.show()
